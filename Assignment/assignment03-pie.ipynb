# %% [markdown]
# # First thing we need to import pandas and matplotlib

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
# We need to load csv file into python. I use read csv file to use the link. Other option is to donwload the file adn open it
emails = pd.read_csv("https://drive.google.com/uc?id=1AWPf-pJodJKeHsARQK_RHiNsE8fjPCVK&export=download")

# %%
# Using the column sex we can create a pie chart. Value count is used to conver objects in numbers
emails ["Sex"].value_counts().plot.pie(autopct='%1.1f%%')
plt.legend(loc="upper left")
plt.ylabel("Emails by Sex")
plt.title("Percentage of emails by Sex")
# Out:
# Text(0.5, 1.0, 'Percentage of emails by Sex')
